# %%
import torch
from matplotlib import pyplot as plt
import numpy as np
import cv2

# %%
# !git clone https://github.com/ultralytics/yolov5

# %%
# GPU bilgilerini almak için bu kodu çalıştırın
import tensorflow as tf
tf.test.gpu_device_name()
# Out:
# ''

# %%
model = torch.hub.load('ultralytics/yolov5', 'yolov5s')
# Out:
# Using cache found in C:\Users\Asus/.cache\torch\hub\ultralytics_yolov5_master
# YOLOv5  2023-12-17 Python-3.9.12 torch-2.1.1 CPU
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients, 16.4 GFLOPs
# Adding AutoShape...

# %%
 model
# Out:
# AutoShape(
#   (model): DetectMultiBackend(
#     (model): DetectionModel(
#       (model): Sequential(
#         (0): Conv(
#           (conv): Conv2d(3, 32, kernel_size=(6, 6), stride=(2, 2), padding=(2, 2))
#           (act): SiLU(inplace=True)
#         )
#         (1): Conv(
#           (conv): Conv2d(32, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#           (act): SiLU(inplace=True)
#         )
#         (2): C3(
#           (cv1): Conv(
#             (conv): Conv2d(64, 32, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(64, 32, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv3): Conv(
#             (conv): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (m): Sequential(
#             (0): Bottleneck(
#               (cv1): Conv(
# ...

# %%
import uuid  # Kaydedilen resimler üst üste binmesin diye ekledik.
import os
import time

# %%
IMAGES_PATH = os.path.join('data', 'images')
labels = ['uyanık', 'uykulu']
number_imgs = 20

# %%
cap = cv2.VideoCapture(0)

for label in labels:
    print('{} için toplanan resimler'.format(label))
    time.sleep(5)

    for img_num in range(number_imgs):
        print('{} için toplanan resimler, resim numarası {}'.format(label, img_num))

        ret, frame = cap.read()

        imgname = os.path.join(IMAGES_PATH, label+'.'+str(uuid.uuid1())+'.jpg')

        cv2.imwrite(imgname, frame)

        cv2.imshow('Toplanan resimler', frame)

        time.sleep(2)

    if cv2.waitKey(10) & 0xFF == ord('q'):
        break
cap.release()
cv2.destroyAllWindows()

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# Google Drive'da yolov5 dizinine geç
os.chdir("/content/drive/MyDrive/YOLO/Uyku_Tespiti/yolov5")

# %%
# !python train.py --img 320 --batch 64 --epochs 1500 --data data.yaml --weights yolov5s.pt --workers 2

# %%
# Modeli manuel olarak yükle
model = torch.hub.load('ultralytics/yolov5:master', 'custom', path='/content/drive/MyDrive/Uyku_Tespiti/yolov5/runs/train/exp6/weights/best.pt')

# %%
model = torch.hub.load('ultralytics/yolov5:master', 'custom', path=r'C:\Users\Asus\OneDrive\Masaüstü\EĞİTİM\3.gün\Uyku_Tespiti\yolov5\runs\train\exp6\weights\best.pt')
# Out:
# Using cache found in C:\Users\Asus/.cache\torch\hub\ultralytics_yolov5_master
# YOLOv5  2023-12-17 Python-3.9.12 torch-2.1.1 CPU
#
# Fusing layers...
# Model summary: 157 layers, 7015519 parameters, 0 gradients, 15.8 GFLOPs
# Adding AutoShape...

# %%
img = os.path.join('data','test', 'images', 'uykulu-9e7f12c2-9fda-11ee-bffc-90e8683d707e_jpg.rf.37d0899f2d10f6dd87bf5c2c516039b0.jpg')

# %%
results = model(img)
results.print()
# Out:
# image 1/1: 640x640 1 Uykulu
# Speed: 55.0ms pre-process, 512.4ms inference, 31.2ms NMS per image at shape (1, 3, 640, 640)

# %%
# %matplotlib inline
plt.imshow(np.squeeze(results.render()))
plt.show()

# %%
cap = cv2.VideoCapture(0)
while cap.isOpened():
    ret, frame = cap.read()

    # Make detections
    results = model(frame)

    cv2.imshow('YOLO', np.squeeze(results.render()))

    if cv2.waitKey(10) & 0xFF == ord('q'):
        break
cap.release()
cv2.destroyAllWindows()
